# %%
import psycopg2

connection = psycopg2.connect(
    host='localhost',
    user='postgres',
    password='*******',
    dbname='classicmodels',
)
cursor = connection.cursor()

# %%
cursor.execute("SELECT productname, quantityinstock, buyprice FROM products WHERE productline = 'Motorcycles'")
print("Products from the Motorcycles line:\n")
for row in cursor:
    print(f'{row[0]:45} | {row[1]:8} | {row[2]:8}')
print()
# Out:
# Products from the Motorcycles line:
#
# 1969 Harley Davidson Ultimate Chopper         |     7933 |    48.81
# 1996 Moto Guzzi 1100i                         |     6625 |    68.99
# 2003 Harley-Davidson Eagle Drag Bike          |     5582 |    91.02
# 2002 Suzuki XREO                              |     9997 |    66.27
# 1936 Harley Davidson El Knucklehead           |     4357 |    24.23
# 1957 Vespa GS150                              |     7689 |    32.95
# 1997 BMW R 1100 S                             |     7003 |    60.86
# 1960 BSA Gold Star DBD34                      |       15 |    37.32
# 1982 Ducati 900 Monster                       |     6840 |     47.1
# 1997 BMW F650 ST                              |      178 |    66.92
# 1982 Ducati 996 R                             |     9241 |    24.14
# 1974 Ducati 350 Mk3 Desmo                     |     3341 |    56.13
# 2002 Yamaha YZR M1                            |      600 |    34.17

# %%
print()
cursor.execute("SELECT ordernumber, status, orderdate FROM orders where  orderdate BETWEEN '2003-01-01' AND '2003-12-31' ORDER BY orderdate, status LIMIT 10")
print("Orders by status and date:\n")
for row in cursor:
    print(f'{row[0]} | {row[1]:10} | {row[2].strftime("%Y-%m-%d")}')
print()
# Out:
# Orders by status and date:
#
# 10100 | Shipped    | 2003-01-06
# 10101 | Shipped    | 2003-01-09
# 10102 | Shipped    | 2003-01-10
# 10103 | Shipped    | 2003-01-29
# 10104 | Shipped    | 2003-01-31
# 10105 | Shipped    | 2003-02-11
# 10106 | Shipped    | 2003-02-17
# 10107 | Shipped    | 2003-02-24
# 10108 | Shipped    | 2003-03-03
# 10109 | Shipped    | 2003-03-10

# %%
cursor.execute("SELECT ordernumber, orderdate, status FROM orders where  orderdate BETWEEN '2003-01-01' AND '2003-12-31' AND status = 'Cancelled'")
print("Cancelled orders placed between 2003-01-01 and 2003-12-31:\n")
for row in cursor:
    print(f'{row[2]} | {row[0]:5} | {row[1].strftime("%Y-%m-%d")}')
# Out:
# Cancelled orders placed between 2003-01-01 and 2003-12-31:
#
# Cancelled | 10167 | 2003-10-23
# Cancelled | 10179 | 2003-11-11

# %%
# average purchase price (buyPrice) of the product

sql="SELECT AVG(buyprice) FROM PRODUCTS"
cursor = connection.cursor()
cursor.execute(sql)
for row in cursor:
    print("Average purchase price of the product: " ,round(row[0],2))
# Out:
# Average purchase price of the product:  54.4

# %%
# the most expensive and cheapest (looking at the MRSP - Manufacturers Suggested Retail Price) product sold by the company

import math

cursor.execute("select msrp from products")
max_price = 0
min_price = math.inf

for row in cursor:
    if row[0] < min_price:
        min_price = row[0]
    if row[0] > max_price:
        max_price = row[0]
        
print(f"Highest price: {max_price}")
print(f"Lowest price: {min_price}")
# Out:
# Highest price: 214.3
# Lowest price: 33.19

# %%
# showing types of product, quantity, price and name 
print("Types of product, quantity, price and name:\n")
cursor.execute('SELECT PL.productline, PR.quantityinstock, PR.buyprice, PR.productname  FROM products PR JOIN productlines PL ON PR.productline = PL.productline ORDER BY PL.productline, PR.productname')

for row in cursor:
    print(f'{row[0]:20} | {row[1]:8} | {row[2]:8} | {row[3]:45}')
print()
# Out:
# Types of product, quantity, price and name:
#
# Classic Cars         |     8826 |     53.9 | 1948 Porsche 356-A Roadster
# Classic Cars         |     8990 |    62.16 | 1948 Porsche Type 356 Roadster
# Classic Cars         |     2350 |    47.25 | 1949 Jaguar XK 120
# Classic Cars         |     7305 |    98.58 | 1952 Alpine Renault 1300
# Classic Cars         |     1452 |    72.82 | 1952 Citroen-15CV
# Classic Cars         |     6600 |     98.3 | 1956 Porsche 356A Coupe
# Classic Cars         |     1249 |    69.93 | 1957 Corvette Convertible
# Classic Cars         |     3209 |    34.21 | 1957 Ford Thunderbird
# Classic Cars         |     2542 |    15.91 | 1958 Chevy Corvette Limited Edition
# Classic Cars         |     7869 |    32.33 | 1961 Chevrolet Impala
# Classic Cars         |     6791 |   103.42 | 1962 LanciaA Delta 16V
# Classic Cars         |     9042 |    65.96 | 1965 Aston Martin DB5
# Classic Cars         |     8197 |    29.18 | 1966 Shelby Cobra 427 S/C
# Classic Cars         |     9123 |    75.16 | 1968 Dodge Charger
# Classic Cars         |       68 |    95.34 | 1968 Ford Mustang
# Classic Cars         |     4695 |    50.51 | 1969 Chevrolet Camaro Z28
# Classic Cars         |     6906 |    89.14 | 1969 Corvair Monza
# Classic Cars         |     7323 |    58.73 | 1969 Dodge Charger
# Classic Cars         |     1917 |    49.05 | 1969 Dodge Super Bee
# Classic Cars         |     1049 |    83.05 | 1969 Ford Falcon
# Classic Cars         |     1005 |    49.24 | 1970 Chevy Chevelle SS 454
# Classic Cars         |     4074 |    32.37 | 1970 Dodge Coronet
# Classic Cars         |     5663 |    31.92 | 1970 Plymouth Hemi Cuda
# Classic Cars         |     5545 |    91.92 | 1970 Triumph Spitfire
# Classic Cars         |     7995 |    38.58 | 1971 Alpine Renault 1600s
# Classic Cars         |     3252 |    85.68 | 1972 Alfa Romeo GTA
# Classic Cars         |     9127 |    73.49 | 1976 Ford Gran Torino
# Classic Cars         |     6934 |    46.53 | 1982 Camaro Z28
# Classic Cars         |     7723 |    16.24 | 1982 Lamborghini Diablo
# Classic Cars         |     7733 |    57.01 | 1985 Toyota Supra
# Classic Cars         |     8347 |     77.9 | 1992 Ferrari 360 Spider red
# Classic Cars         |     6582 |    69.78 | 1992 Porsche Cayenne Turbo Silver
# Classic Cars         |     3975 |    83.51 | 1993 Mazda RX-7
# Classic Cars         |     9772 |    93.89 | 1995 Honda Civic
# Classic Cars         |     4724 |   101.51 | 1998 Chrysler Plymouth Prowler
# Classic Cars         |     8164 |    56.76 | 1999 Indy 500 Monte Carlo SS
# Classic Cars         |     3619 |    95.59 | 2001 Ferrari Enzo
# Classic Cars         |     9446 |    62.11 | 2002 Chevy Corvette
# Motorcycles          |     4357 |    24.23 | 1936 Harley Davidson El Knucklehead
# Motorcycles          |     7689 |    32.95 | 1957 Vespa GS150
# Motorcycles          |       15 |    37.32 | 1960 BSA Gold Star DBD34
# Motorcycles          |     7933 |    48.81 | 1969 Harley Davidson Ultimate Chopper
# Motorcycles          |     3341 |    56.13 | 1974 Ducati 350 Mk3 Desmo
# Motorcycles          |     6840 |     47.1 | 1982 Ducati 900 Monster
# Motorcycles          |     9241 |    24.14 | 1982 Ducati 996 R
# Motorcycles          |     6625 |    68.99 | 1996 Moto Guzzi 1100i
# Motorcycles          |      178 |    66.92 | 1997 BMW F650 ST
# Motorcycles          |     7003 |    60.86 | 1997 BMW R 1100 S
# Motorcycles          |     9997 |    66.27 | 2002 Suzuki XREO
# Motorcycles          |      600 |    34.17 | 2002 Yamaha YZR M1
# Motorcycles          |     5582 |    91.02 | 2003 Harley-Davidson Eagle Drag Bike
# Planes               |     5942 |    34.25 | 1900s Vintage Bi-Plane
# Planes               |     2756 |    36.23 | 1900s Vintage Tri-Plane
# Planes               |     3627 |    66.74 | 1928 British Royal Navy Airplane
# Planes               |     5330 |    77.27 | 1980s Black Hawk Helicopter
# Planes               |     7106 |    59.33 | ATA: B757-300
# Planes               |     9653 |     68.8 | America West Airlines B757-200
# Planes               |     5841 |    51.15 | American Airlines: B767-300
# Planes               |     8820 |    36.27 | American Airlines: MD-11S
# Planes               |     4857 |    32.77 | Boeing X-32A JSF
# Planes               |     6812 |    29.34 | Corsair F4U ( Bird Cage)
# Planes               |      551 |     54.4 | F/A 18 Hornet 1/72
# Planes               |      992 |     49.0 | P-51-D Mustang
# Ships                |     1898 |    82.34 | 18th century schooner
# Ships                |     4259 |    51.61 | 1999 Yamaha Speed Boat
# Ships                |     3501 |    39.83 | HMS Bounty
# Ships                |      414 |     33.3 | Pont Yacht
# Ships                |      737 |     43.3 | The Mayflower
# Ships                |     5088 |    53.63 | The Queen Mary
# Ships                |     1897 |     34.0 | The Schooner Bluenose
# Ships                |     1956 |    51.09 | The Titanic
# Ships                |     7083 |    33.97 | The USS Constitution Ship
# Trains               |     8601 |    26.72 | 1950's Chicago Surface Lines Streetcar
# Trains               |     1645 |    37.49 | 1962 City of Detroit Streetcar
# Trains               |     6450 |    67.56 | Collectable Wooden Train
# Trucks and Buses     |        0 |    24.92 | 1926 Ford Fire Engine
# Trucks and Buses     |        0 |    58.33 | 1940 Ford Pickup Truck
# Trucks and Buses     |        0 |    84.76 | 1940s Ford truck
# Trucks and Buses     |        0 |    25.98 | 1954 Greyhound Scenicruiser
# Trucks and Buses     |        0 |     55.7 | 1957 Chevy Pickup
# Trucks and Buses     |        0 |     77.9 | 1958 Setra Bus
# Trucks and Buses     |        0 |    61.34 | 1962 Volkswagen Microbus
# Trucks and Buses     |        0 |    74.86 | 1964 Mercedes Tour Bus
# Trucks and Buses     |        0 |    53.93 | 1980s GM Manhattan Express
# Trucks and Buses     |        0 |    33.61 | 1996 Peterbilt 379 Stake Bed with Outrigger
# Trucks and Buses     |        0 |    68.29 | Diamond T620 Semi-Skirted Tanker
# Vintage Cars         |     5992 |    60.74 | 18th Century Vintage Horse Carriage
# Vintage Cars         |     3913 |     68.3 | 1903 Ford Model A
# Vintage Cars         |     8290 |    52.66 | 1904 Buick Runabout
# Vintage Cars         |      540 |     33.3 | 1911 Ford Town Car
# Vintage Cars         |     9173 |    46.91 | 1912 Ford Model T Delivery Wagon
# Vintage Cars         |     4189 |    60.78 | 1913 Ford Model T Speedster
# Vintage Cars         |     2724 |     86.7 | 1917 Grand Touring Sedan
# Vintage Cars         |     7913 |    57.54 | 1917 Maxwell Touring Car
# Vintage Cars         |      136 |    33.02 | 1928 Ford Phaeton Deluxe
# Vintage Cars         |      548 |    72.56 | 1928 Mercedes-Benz SSK
# Vintage Cars         |     7062 |    27.06 | 1930 Buick Marquette Phaeton
# Vintage Cars         |     6553 |    43.26 | 1932 Alfa Romeo 8C2300 Spider Sport
# Vintage Cars         |     9354 |    58.48 | 1932 Model A Ford J-Coupe
# Vintage Cars         |     5649 |    34.35 | 1934 Ford V8 Coupe
# Vintage Cars         |     4710 |    57.46 | 1936 Chrysler Airflow
# Vintage Cars         |     2081 |    21.75 | 1936 Mercedes Benz 500k Roadster
# Vintage Cars         |     8635 |    24.26 | 1936 Mercedes-Benz 500K Special Roadster
# Vintage Cars         |     2902 |     26.3 | 1937 Horch 930V Limousine
# Vintage Cars         |     8693 |    60.62 | 1937 Lincoln Berline
# Vintage Cars         |     2847 |    20.61 | 1938 Cadillac V-16 Presidential Limousine
# Vintage Cars         |     6645 |    23.14 | 1939 Cadillac Limousine
# Vintage Cars         |     7332 |    22.57 | 1939 Chevrolet Deluxe Coupe
# Vintage Cars         |     6621 |    48.64 | 1940 Ford Delivery Sedan
# Vintage Cars         |     2378 |    64.58 | 1941 Chevrolet Special Deluxe Cabriolet

# %%
# finding employees responsible for each customer
print("Employees responsible for each customer:\n")
cursor.execute('SELECT C.customernumber, C.customername, E.firstname, E.lastname, E.email FROM customers C JOIN employees E ON C.salesrepemployeenumber = E.employeenumber ORDER BY C.customername')
for row in cursor:
    print(row[0],f'| {row[1]:35} | {row[2]:10} {row[3]:10} | {row[4]}')
print()
# Out:
# Employees responsible for each customer:
#
# 187 | AV Stores, Co.                      | Larry      Bott       | lbott@classicmodelcars.com
# 242 | Alpha Cognac                        | Gerard     Hernandez  | ghernande@classicmodelcars.com
# 168 | American Souvenirs Inc              | Foon Yue   Tseng      | ftseng@classicmodelcars.com
# 249 | Amica Models & Co.                  | Pamela     Castillo   | pcastillo@classicmodelcars.com
# 276 | Anna's Decorations, Ltd             | Andy       Fixter     | afixter@classicmodelcars.com
# 103 | Atelier graphique                   | Gerard     Hernandez  | ghernande@classicmodelcars.com
# 471 | Australian Collectables, Ltd        | Andy       Fixter     | afixter@classicmodelcars.com
# 114 | Australian Collectors, Co.          | Andy       Fixter     | afixter@classicmodelcars.com
# 333 | Australian Gift Network, Co         | Andy       Fixter     | afixter@classicmodelcars.com
# 256 | Auto Associés & Cie.                | Gerard     Hernandez  | ghernande@classicmodelcars.com
# 406 | Auto Canal+ Petit                   | Loui       Bondur     | lbondur@classicmodelcars.com
# 198 | Auto-Moto Classics Inc.             | Steve      Patterson  | spatterson@classicmodelcars.com
# 121 | Baane Mini Imports                  | Barry      Jones      | bjones@classicmodelcars.com
# 415 | Bavarian Collectables Imports, Co.  | Barry      Jones      | bjones@classicmodelcars.com
# 128 | Blauer See Auto, Co.                | Barry      Jones      | bjones@classicmodelcars.com
# 219 | Boards & Toys Co.                   | Leslie     Thompson   | lthompson@classicmodelcars.com
# 344 | CAF Imports                         | Martin     Gerard     | mgerard@classicmodelcars.com
# 173 | Cambridge Collectables Co.          | Julie      Firrelli   | jfirrelli@classicmodelcars.com
# 202 | Canadian Gift Exchange Network      | George     Vanauf     | gvanauf@classicmodelcars.com
# 339 | Classic Gift Ideas, Inc             | Julie      Firrelli   | jfirrelli@classicmodelcars.com
# 424 | Classic Legends Inc.                | Foon Yue   Tseng      | ftseng@classicmodelcars.com
# 189 | Clover Collections, Co.             | Barry      Jones      | bjones@classicmodelcars.com
# 239 | Collectable Mini Designs Co.        | Leslie     Thompson   | lthompson@classicmodelcars.com
# 379 | Collectables For Less Inc.          | Julie      Firrelli   | jfirrelli@classicmodelcars.com
# 321 | Corporate Gift Ideas Co.            | Leslie     Jennings   | ljennings@classicmodelcars.com
# 458 | Corrida Auto Replicas, Ltd          | Martin     Gerard     | mgerard@classicmodelcars.com
# 385 | Cruz & Sons Co.                     | Mami       Nishi      | mnishi@classicmodelcars.com
# 171 | Daedalus Designs Imports            | Gerard     Hernandez  | ghernande@classicmodelcars.com
# 145 | Danish Wholesale Imports            | Pamela     Castillo   | pcastillo@classicmodelcars.com
# 157 | Diecast Classics Inc.               | Steve      Patterson  | spatterson@classicmodelcars.com
# 495 | Diecast Collectables                | Julie      Firrelli   | jfirrelli@classicmodelcars.com
# 489 | Double Decker Gift Stores, Ltd      | Larry      Bott       | lbott@classicmodelcars.com
# 323 | Down Under Souveniers, Inc          | Peter      Marsh      | pmarsh@classicmodelcars.com
# 148 | Dragon Souveniers, Ltd.             | Mami       Nishi      | mnishi@classicmodelcars.com
# 216 | Enaco Distributors                  | Martin     Gerard     | mgerard@classicmodelcars.com
# 141 | Euro+ Shopping Channel              | Gerard     Hernandez  | ghernande@classicmodelcars.com
# 412 | Extreme Desk Decorations, Ltd       | Peter      Marsh      | pmarsh@classicmodelcars.com
# 473 | Frau da Collezione                  | Pamela     Castillo   | pcastillo@classicmodelcars.com
# 462 | FunGiftIdeas.com                    | Steve      Patterson  | spatterson@classicmodelcars.com
# 175 | Gift Depot Inc.                     | George     Vanauf     | gvanauf@classicmodelcars.com
# 447 | Gift Ideas Corp.                    | George     Vanauf     | gvanauf@classicmodelcars.com
# 362 | Gifts4AllAges.com                   | Steve      Patterson  | spatterson@classicmodelcars.com
# 357 | GiftsForHim.com                     | Peter      Marsh      | pmarsh@classicmodelcars.com
# 166 | Handji Gifts& Co                    | Peter      Marsh      | pmarsh@classicmodelcars.com
# 227 | Heintze Collectables                | Pamela     Castillo   | pcastillo@classicmodelcars.com
# 167 | Herkku Gifts                        | Barry      Jones      | bjones@classicmodelcars.com
# 484 | Iberia Gift Imports, Corp.          | Martin     Gerard     | mgerard@classicmodelcars.com
# 496 | Kelly's Gift Shop                   | Peter      Marsh      | pmarsh@classicmodelcars.com
# 211 | King Kong Collectables, Co.         | Mami       Nishi      | mnishi@classicmodelcars.com
# 386 | L'ordine Souveniers                 | Pamela     Castillo   | pcastillo@classicmodelcars.com
# 172 | La Corne D'abondance, Co.           | Loui       Bondur     | lbondur@classicmodelcars.com
# 119 | La Rochelle Gifts                   | Gerard     Hernandez  | ghernande@classicmodelcars.com
# 131 | Land of Toys Inc.                   | George     Vanauf     | gvanauf@classicmodelcars.com
# 250 | Lyon Souveniers                     | Loui       Bondur     | lbondur@classicmodelcars.com
# 350 | Marseille Mini Autos                | Loui       Bondur     | lbondur@classicmodelcars.com
# 286 | Marta's Replicas Co.                | Steve      Patterson  | spatterson@classicmodelcars.com
# 347 | Men 'R' US Retailers, Ltd.          | Leslie     Thompson   | lthompson@classicmodelcars.com
# 456 | Microscale Inc.                     | Foon Yue   Tseng      | ftseng@classicmodelcars.com
# 452 | Mini Auto Werke                     | Pamela     Castillo   | pcastillo@classicmodelcars.com
# 209 | Mini Caravy                         | Gerard     Hernandez  | ghernande@classicmodelcars.com
# 319 | Mini Classics                       | George     Vanauf     | gvanauf@classicmodelcars.com
# 320 | Mini Creations Ltd.                 | Julie      Firrelli   | jfirrelli@classicmodelcars.com
# 124 | Mini Gifts Distributors Ltd.        | Leslie     Jennings   | ljennings@classicmodelcars.com
# 129 | Mini Wheels Co.                     | Leslie     Jennings   | ljennings@classicmodelcars.com
# 486 | Motor Mint Distributors Inc.        | George     Vanauf     | gvanauf@classicmodelcars.com
# 151 | Muscle Machine Inc                  | Foon Yue   Tseng      | ftseng@classicmodelcars.com
# 299 | Norway Gifts By Mail, Co.           | Barry      Jones      | bjones@classicmodelcars.com
# 363 | Online Diecast Creations Co.        | Steve      Patterson  | spatterson@classicmodelcars.com
# 204 | Online Mini Collectables            | Julie      Firrelli   | jfirrelli@classicmodelcars.com
# 177 | Osaka Souveniers Co.                | Mami       Nishi      | mnishi@classicmodelcars.com
# 311 | Oulu Toy Supplies, Inc.             | Larry      Bott       | lbott@classicmodelcars.com
# 314 | Petit Auto                          | Pamela     Castillo   | pcastillo@classicmodelcars.com
# 376 | Precious Collectables               | Martin     Gerard     | mgerard@classicmodelcars.com
# 233 | Québec Home Shopping Network        | Foon Yue   Tseng      | ftseng@classicmodelcars.com
# 353 | Reims Collectables                  | Loui       Bondur     | lbondur@classicmodelcars.com
# 278 | Rovelli Gifts                       | Pamela     Castillo   | pcastillo@classicmodelcars.com
# 260 | Royal Canadian Collectables, Ltd.   | George     Vanauf     | gvanauf@classicmodelcars.com
# 381 | Royale Belge                        | Pamela     Castillo   | pcastillo@classicmodelcars.com
# 382 | Salzburg Collectables               | Pamela     Castillo   | pcastillo@classicmodelcars.com
# 146 | Saveley & Henriot, Co.              | Loui       Bondur     | lbondur@classicmodelcars.com
# 448 | Scandinavian Gift Ideas             | Barry      Jones      | bjones@classicmodelcars.com
# 487 | Signal Collectibles Ltd.            | Leslie     Jennings   | ljennings@classicmodelcars.com
# 112 | Signal Gift Stores                  | Leslie     Thompson   | lthompson@classicmodelcars.com
# 282 | Souveniers And Things Co.           | Andy       Fixter     | afixter@classicmodelcars.com
# 324 | Stylish Desk Decors, Co.            | Larry      Bott       | lbott@classicmodelcars.com
# 334 | Suominen Souveniers                 | Larry      Bott       | lbott@classicmodelcars.com
# 455 | Super Scale Inc.                    | Foon Yue   Tseng      | ftseng@classicmodelcars.com
# 161 | Technics Stores Inc.                | Leslie     Jennings   | ljennings@classicmodelcars.com
# 328 | Tekni Collectables Inc.             | George     Vanauf     | gvanauf@classicmodelcars.com
# 450 | The Sharp Gifts Warehouse           | Leslie     Jennings   | ljennings@classicmodelcars.com
# 259 | Toms Spezialitäten, Ltd             | Barry      Jones      | bjones@classicmodelcars.com
# 186 | Toys of Finland, Co.                | Larry      Bott       | lbott@classicmodelcars.com
# 205 | Toys4GrownUps.com                   | Leslie     Thompson   | lthompson@classicmodelcars.com
# 201 | UK Collectables, Ltd.               | Larry      Bott       | lbott@classicmodelcars.com
# 298 | Vida Sport, Ltd                     | Martin     Gerard     | mgerard@classicmodelcars.com
# 181 | Vitachrome Inc.                     | Foon Yue   Tseng      | ftseng@classicmodelcars.com
# 144 | Volvo Model Replicas, Co            | Barry      Jones      | bjones@classicmodelcars.com
# 475 | West Coast Collectables Co.         | Leslie     Thompson   | lthompson@classicmodelcars.com
# 240 | giftsbymail.co.uk                   | Larry      Bott       | lbott@classicmodelcars.com

# %%
# checking whether all employees are assigned to a certain office
print("Employees and the offices they are assigned to:\n")
cursor.execute('SELECT O.officecode, O.city, E.firstname, E.lastname FROM employees E FULL OUTER JOIN offices O ON E.officecode = O.officecode' )
for row in cursor:
    print(f'{row[0]:3} {row[1]:15} {row[2]:10} {row[3]:10}')
# Out:
# Employees and the offices they are assigned to:
#
# 1   San Francisco   Diane      Murphy
# 1   San Francisco   Mary       Patterson
# 1   San Francisco   Jeff       Firrelli
# 6   Sydney          William    Patterson
# 4   Paris           Gerard     Bondur
# 1   San Francisco   Anthony    Bow
# 1   San Francisco   Leslie     Jennings
# 1   San Francisco   Leslie     Thompson
# 2   Boston          Julie      Firrelli
# 2   Boston          Steve      Patterson
# 3   NYC             Foon Yue   Tseng
# 3   NYC             George     Vanauf
# 4   Paris           Loui       Bondur
# 4   Paris           Gerard     Hernandez
# 4   Paris           Pamela     Castillo
# 7   London          Barry      Jones
# 6   Sydney          Andy       Fixter
# 6   Sydney          Peter      Marsh
# 6   Sydney          Tom        King
# 5   Tokyo           Mami       Nishi
# 5   Tokyo           Yoshimi    Kato
# 4   Paris           Martin     Gerard
# 7   London          Larry      Bott
